# %% [markdown]
# <a href="https://colab.research.google.com/github/Luizfilipe99/C11/blob/main/Exercicio_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dfpaises = pd.read_csv('paises.csv', delimiter=';')
print(dfpaises.columns)
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
print(dfpaises['Deathrate'])
# Out:
# 0      20.34
# 1       5.22
# 2       4.61
# 3       3.27
# 4       6.25
#        ...
# 222     3.92
# 223     0.00
# 224     8.30
# 225    19.93
# 226    21.84
# Name: Deathrate, Length: 227, dtype: float64

# %% [markdown]
# #execicio 1

# %%
regian = dfpaises['Region'].str.contains('OCEANIA')
series = dfpaises[regian]
print(series['Country'])
print()
print(len(series['Country']))
# Out:
# 3            American Samoa
# 11                Australia
# 47             Cook Islands
# 67                     Fiji
# 71         French Polynesia
# 83                     Guam
# 108                Kiribati
# 130        Marshall Islands
# 136    Micronesia, Fed. St.
# 144                   Nauru
# 148           New Caledonia
# 149             New Zealand
# 153      N. Mariana Islands
# 157                   Palau
# 159        Papua New Guinea
# 176                   Samoa
# 187         Solomon Islands
# 203                   Tonga
# 209                  Tuvalu
# 217                 Vanuatu
# 221       Wallis and Futuna
# Name: Country, dtype: object
#
# 21

# %% [markdown]
# #Exercico 2

# %%
maior = max(dfpaises['Population'])
popu = dfpaises['Population'] == maior
population = dfpaises[popu]
print(population['Country']+' '+population['Region'])
# Out:
# 42    China  ASIA (EX. NEAR EAST)
# dtype: object

# %% [markdown]
# #Exercicio 3

# %%
group_region = dfpaises.groupby('Region')
print(group_region['Literacy (%)'].mean())
# Out:
# Region
# ASIA (EX. NEAR EAST)                   79.553571
# BALTICS                                99.733333
# C.W. OF IND. STATES                    98.725000
# EASTERN EUROPE                         72.816667
# LATIN AMER. & CARIB                    88.640000
# NEAR EAST                              69.581250
# NORTHERN AFRICA                        56.033333
# NORTHERN AMERICA                       78.200000
# OCEANIA                                71.914286
# SUB-SAHARAN AFRICA                     61.284314
# WESTERN EUROPE                         80.821429
# Name: Literacy (%), dtype: float64

# %% [markdown]
# #Exercicio 4

# %%
mar = dfpaises['Coastline (coast/area ratio)'] == 0
marinha = dfpaises[mar]
marinha.to_csv('noCoast.csv', sep=';')

# %% [markdown]
# #Exercicio 5

# %%
dfpaises['Humanitarian Help'] = np.where(dfpaises['Deathrate'] < 9 , 'Balanced' , 'Urgent')
print(dfpaises.columns)
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service', 'Humanitarian Help'],
#       dtype='object')
